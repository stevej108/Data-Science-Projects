# %%
import seedir as sd
# print full directory tree of the Productivity Optimization directory
sd.seedir(path='.', style='lines')
# Out:
# Productivity Optimization/
# ├─agents/
# │ ├─discover.py
# │ ├─memo.py
# │ ├─parser.py
# │ ├─rerank_documents.py
# │ ├─retrieve.py
# │ ├─run.py
# │ ├─summarize.py
# │ ├─synthesize.py
# │ ├─workflow.py
# │ └─__init__.py
# ├─core/
# │ ├─config.py
# │ ├─llm.py
# │ ├─logger.py
# │ ├─state.py
# │ └─__init__.py
# ├─helpers/
# │ ├─discovery.py
# │ ├─extraction.py
# │ ├─file_utils.py
# │ ├─parsers.py
# │ ├─ranking.py
# │ ├─retrieval.py
# │ ├─word_helpers.py
# │ └─__init__.py
# ├─notebooks/
# │ └─PowerPoint_Agentic_Parsing.ipynb
# ├─OneDrive_Search.log
# ├─output/
# │ └─memo_Traffic_20260701_110918.docx
# ├─prompts/
# │ ├─document_summary.py
# │ ├─enterprise_synthesis.py
# │ ├─rerank.py
# │ └─__init__.py
# ├─tree.ipynb
# └─ui/
#   ├─app.py
#   └─__init__.py
